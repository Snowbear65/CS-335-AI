# %% [markdown]
# <a href="https://colab.research.google.com/github/Snowbear65/CS-335-AI/blob/main/Build_ZodiacBot_AI_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
#
# Please ensure you have imported a Gemini API key from AI Studio.
# You can do this directly in the Secrets tab on the left.
#
# After doing so, please run the setup cell below.

# %%
# !pip install -U -q "google"
# !pip install -U -q "google.genai"

import os
from google.colab import userdata
from google.colab import drive
os.environ["GEMINI_API_KEY"] = userdata.get("GOOGLE_API_KEY")

drive.mount("/content/drive")
# Please ensure that uploaded files are available in the AI Studio folder or change the working folder.
os.chdir("/content/drive/MyDrive/Google AI Studio")

# %% [markdown]
# # Generated Code

# %%
# To run this code you need to install the following dependencies:
# pip install google-genai

import os
from google import genai
from google.genai import types


def generate():
    client = genai.Client(
        api_key=os.environ.get("GEMINI_API_KEY"),
    )

    model = "gemini-3-flash-preview"
    contents = [
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""You are a CS student in your last semester of college. For CS 335 Artificial Intelligence, build a AI Chatbot. The user should be able to enter their birthdate (Day, month, year) and the chatbot will provide a horoscope based on their Zodiac Sign"""),
            ],
        ),
        types.Content(
            role="model",
            parts=[
                types.Part.from_text(text="""**Defining Zodiac Signs**

Okay, I'm currently focused on defining the twelve Zodiac signs. I'm cross-referencing their corresponding date ranges to solidify the basis for accurate classification. I'm also preparing for the next step, which will involve finding or creating generic horoscope descriptions that can be used.


**Defining Zodiac Dates**

I've got the date ranges for all twelve signs locked down, from Aries to Pisces. I've got the basic horoscope traits associated with each sign, too. The Python code examples for sign calculators and web scraping are helpful. I'm thinking about how to connect these separate pieces.


**Refining the Horoscope Logic**

I'm focused on the \"CS 335\" level aspects now. I'm aiming for clean, documented Python code, possibly incorporating functional programming principles. I've decided to use a dictionary for the date-sign mapping and a concise `get_zodiac_sign()` function. I can create diverse horoscopes from existing templates. An AI component could involve a rule-based system or even a mention of integrating an LLM, though that's a future possibility.


**Structuring the Response**

I'm now prioritizing the structure of the output. For a fundamental request, I'm developing a robust, rule-based Python script with a clean command-line interface as the central element. I'm carefully organizing the code and its accompanying explanation to meet the standards of a senior project, including the code itself. I'm focused on the basic structure now, and will ensure it includes all date ranges. I am testing the Capricorn range to handle year transitions.


"""),
                types.Part.from_text(text="""Hey there! As a fellow senior finishing up CS 335, I totally get the \"last semester\" grind. For an AI course, you usually want something more robust than just a nested `if-else` block—you want clean, modular code that demonstrates good data structure design.

Here is a Python implementation for our **ZodiacBot**. It uses a logic-based engine to classify the user's input and a dictionary-based knowledge base to provide the horoscope.

### The Code (Python)

```python
import datetime

class ZodiacChatbot:
    def __init__(self):
        self.bot_name = \"CosmoBot\"
        # Knowledge Base: Date ranges and Horoscopes
        self.zodiac_data = {
            \"Capricorn\": {\"end_date\": (1, 19), \"msg\": \"Your discipline is your superpower today. A long-term project finally shows progress.\"},
            \"Aquarius\": {\"end_date\": (2, 18), \"msg\": \"Expect a burst of creative energy. A unique solution to a tech problem is coming to you.\"},
            \"Pisces\": {\"end_date\": (3, 20), \"msg\": \"Trust your intuition. Someone close to you needs your empathy more than your logic.\"},
            \"Aries\": {\"end_date\": (4, 19), \"msg\": \"It's a high-energy day! Take the lead on a new project; your confidence is infectious.\"},
            \"Taurus\": {\"end_date\": (5, 20), \"msg\": \"Stability is key today. Avoid impulsive purchases and focus on grounding yourself.\"},
            \"Gemini\": {\"end_list\": (6, 20), \"msg\": \"Communication is your focus. An unexpected message might open a new professional door.\"},
            \"Cancer\": {\"end_date\": (7, 22), \"msg\": \"Home and family take priority today. Recharging your emotional battery is essential.\"},
            \"Leo\": {\"end_date\": (8, 22), \"msg\": \"The spotlight is on you! Don't be afraid to showcase your talents in your next meeting.\"},
            \"Virgo\": {\"end_date\": (9, 22), \"msg\": \"Your attention to detail is sharp today. Perfect time for debugging or organizing your life.\"},
            \"Libra\": {\"end_date\": (10, 22), \"msg\": \"Balance is your goal. A conflict will be resolved if you stay diplomatic and fair.\"},
            \"Scorpio\": {\"end_date\": (11, 21), \"msg\": \"Your focus is intense. Deep research or a serious conversation will yield great results.\"},
            \"Sagittarius\": {\"end_date\": (12, 21), \"msg\": \"Adventure calls! Even a small change in your routine will bring a fresh perspective.\"}
        }

    def get_zodiac(self, day, month):
        \"\"\"Logic to determine sign based on day and month.\"\"\"
        # Using a tuple comparison for clean range logic
        if (month == 12 and day >= 22) or (month == 1 and day <= 19):
            return \"Capricorn\"
        elif (month == 1 and day >= 20) or (month == 2 and day <= 18):
            return \"Aquarius\"
        elif (month == 2 and day >= 19) or (month == 3 and day <= 20):
            return \"Pisces\"
        elif (month == 3 and day >= 21) or (month == 4 and day <= 19):
            return \"Aries\"
        elif (month == 4 and day >= 20) or (month == 5 and day <= 20):
            return \"Taurus\"
        elif (month == 5 and day >= 21) or (month == 6 and day <= 20):
            return \"Gemini\"
        elif (month == 6 and day >= 21) or (month == 7 hide and day <= 22):
            return \"Cancer\"
        elif (month == 7 and day >= 23) or (month == 8 and day <= 22):
            return \"Leo\"
        elif (month == 8 and day >= 23) or (month == 9 and day <= 22):
            return \"Virgo\"
        elif (month == 9 and day >= 23) or (month == 10 and day <= 22):
            return \"Libra\"
        elif (month == 10 and day >= 23) or (month == 11 and day <= 21):
            return \"Scorpio\"
        elif (month == 11 and day >= 22) or (month == 12 and day <= 21):
            return \"Sagittarius\"
        return None

    def start_chat(self):
        print(f\"[{self.bot_name}]: Hello! I am your AI Astrology assistant.\")
        print(f\"[{self.bot_name}]: Please enter your birth details so I can read the stars for you.\")

        try:
            year = int(input(\"Year (YYYY): \"))
            month = int(input(\"Month (1-12): \"))
            day = int(input(\"Day (1-31): \"))

            # Validate date
            birth_date = datetime.date(year, month, day)
            sign = self.get_zodiac(day, month)

            print(f\"\\n[{self.bot_name}]: I've analyzed your birth date: {birth_date.strftime('%B %d, %Y')}.\")
            print(f\"[{self.bot_name}]: Your Zodiac sign is **{sign}**.\")
            print(f\"[{self.bot_name}]: Here is your horoscope: \\\"{self.zodiac_data[sign]['msg']}\\\"\")

        except ValueError:
            print(f\"[{self.bot_name}]: Oops! That doesn't look like a valid date. Please try again.\")

if __name__ == \"__main__\":
    bot = ZodiacChatbot()
    bot.start_chat()
```

### Key Features for your CS 335 Project:
1.  **Data Encapsulation**: I used a class-based approach. This makes it easy to extend later (e.g., adding a database or an external API like `pyaztro`).
2.  **Input Validation**: Using `datetime.date()` is a \"senior-level\" way to handle errors. If a user enters \"February 30th,\" the `ValueError` catch will handle it gracefully instead of the program crashing.
3.  **Efficiency**: The `get_zodiac` function uses simple conditional logic that is $O(1)$ in time complexity, which is efficient for a real-time chatbot.
4.  **Future AI Step**: If your professor asks how to make it \"more AI,\" you can mention that this is a **Rule-Based Expert System**. To upgrade it, you could integrate a Generative AI API (like OpenAI) to generate unique, flowery horoscopes based on the determined sign.

Good luck with the rest of the semester! One more final stretch!"""),
            ],
        ),
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""INSERT_INPUT_HERE"""),
            ],
        ),
    ]
    tools = [
        types.Tool(googleSearch=types.GoogleSearch(
        )),
    ]
    generate_content_config = types.GenerateContentConfig(
        thinking_config=types.ThinkingConfig(
            thinking_level="HIGH",
        ),
        tools=tools,
    )

    for chunk in client.models.generate_content_stream(
        model=model,
        contents=contents,
        config=generate_content_config,
    ):
        print(chunk.text, end="")

if __name__ == "__main__":
    generate()
